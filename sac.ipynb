# %% [markdown]
# <a href="https://colab.research.google.com/github/isac12345/karepeNT/blob/main/sac.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv

dataset = '/content/sample_data/Tweets.csv'
with open(dataset) as inisial_file:
   baca_file = csv.reader(inisial_file, delimiter=',')
   for baris in baca_file:
    print(baris)
# Out:
# Streaming output truncated to the last 5000 lines.
# ['rihanna', 'she + AK http://t.co/XwLyjRF5rm', '', '07/08/2013 12:56', '3.65094E+17', 'in', '', '', '924', '1217']
# ['rihanna', 'Up watching Cocaine Cowboyz #KillinDeseHeauxz #phuckyogrill… http://t.co/hDSdIrSmVA', '', '07/08/2013 12:53', '3.65093E+17', 'en', '', '', '817', '1002']
# ['rihanna', 'A taste of Heauxm #Barbados #Chefette #IslandGal http://t.co/1wDO87TVEb', '', '06/08/2013 22:28', '3.64876E+17', 'en', '', '', '896', '1032']
# ['rihanna', 'Dear, the love of my life! There will never be another us!!! @jennnrosales http://t.co/BjlcESqBI0', '', '06/08/2013 11:30', '3.6471E+17', 'en', '', '', '1046', '1165']
# ['rihanna', "He's legendary, and he loves me, just the way I am! http://t.co/pyXpvOd0AT", '', '06/08/2013 11:03', '3.64703E+17', 'en', '', '', '1115', '1272']
# ['rihanna', 'Best phucking friendz 4Life @mforde11 http://t.co/isqpmutc0H', '', '06/08/2013 10:52', '3.64701E+17', 'en', '', '', '1013', '1111']
# ...
